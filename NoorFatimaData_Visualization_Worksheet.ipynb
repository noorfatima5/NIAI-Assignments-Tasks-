# %% [markdown]
# # 📊 Data Visualization — Practice Worksheet
# ### Tasks covering Matplotlib, Seaborn, Bokeh & Plotly
#
# ---
#
# > 📌 **Instructions**
# > - Complete **all 9 tasks** in order.
# > - Each task builds on concepts covered in the lecture.
# > - Fill in the `# YOUR CODE HERE` sections only — do not change the task descriptions.
# > - Run each cell after completing it to verify your output.
#
# **Libraries you will need:** `matplotlib`, `seaborn`, `bokeh`, `plotly`

# %% [markdown]
# ## ⚙️ Setup — Run This First
#
# Import all required libraries before starting the tasks.

# %% [markdown]
# ---
# ## 📝 Task 1 — Multi-Line Plot with Matplotlib
#
# ### Background
# Line plots are used to show **trends over time**. When comparing multiple series on the same chart you add a legend so readers can distinguish them.
#
# ### 🎯 Your Task
# The table below shows the **monthly revenue** (in $000s) of two products over 6 months.
#
# | Month | Product A | Product B |
# |-------|-----------|-----------|
# | Jan | 15 | 10 |
# | Feb | 18 | 13 |
# | Mar | 14 | 16 |
# | Apr | 22 | 18 |
# | May | 25 | 20 |
# | Jun | 28 | 24 |
#
# Create a **single line chart** that shows **both products** with:
# - Different colors and markers for each line
# - A legend identifying each product
# - Proper axis labels and a descriptive title
# - Grid lines enabled
#
# > 💡 **Hint:** Plot both series with `plt.plot()` twice, passing `label=` each time, then call `plt.legend()`.

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
product_a = [15, 18, 14, 22, 25, 28]
product_b = [10, 13, 16, 18, 20, 24]

# YOUR CODE HERE
# Plot Product A line (choose any color and marker)
plt.plot(months, product_a, marker='o', label='Product A')

# Plot Product B line (choose a different color and marker)
plt.plot(months, product_b, marker='s', label='Product B')

# Add title, axis labels, legend, and grid
plt.xlabel("Month")
plt.ylabel("Revenue ($000s)")
plt.title("Monthly Revenue Comparison of Product A and Product B")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 2 — Grouped Bar Chart with Matplotlib
#
# ### Background
# A **grouped bar chart** places multiple bars side by side for the same category, making it easy to compare values within each group.
#
# ### 🎯 Your Task
# The data below shows **exam scores** for three subjects across two classes.
#
# | Subject | Class A | Class B |
# |---------|---------|---------|
# | Math | 72 | 68 |
# | Science | 85 | 80 |
# | English | 78 | 74 |
# | History | 65 | 70 |
#
# Create a **grouped bar chart** with:
# - Two bars (Class A and Class B) side by side for each subject
# - Different colors for each class
# - Value labels on top of each bar
# - A legend, axis labels, and a title
#
# > 💡 **Hint:** Use `np.arange(len(subjects))` for x-positions, then offset each group with `x - 0.2` and `x + 0.2` and `width=0.4`.
# > To add labels: loop over bars using `bar.get_height()` and `plt.text()`.

# %%
import numpy as np
import matplotlib.pyplot as plt
subjects = ['Math', 'Science', 'English', 'History']
class_a  = [72, 85, 78, 65]
class_b  = [68, 80, 74, 70]

# YOUR CODE HERE
# Create x positions using np.arange
x = np.arange(len(subjects))
width = 0.4
# Plot Class A bars (offset left)
bars1 = plt.bar(x - 0.2, class_a, width=width, label="Class A")

# Plot Class B bars (offset right)
bars2 = plt.bar(x + 0.2, class_b, width=width, label="Class B")
# Add value labels above each bar
for bar in bars1:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, height,
             ha='center', va='bottom')

for bar in bars2:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, height,
             ha='center', va='bottom')


# Add title, axis labels, legend, and x-tick labels

plt.xticks(x, subjects)
plt.xlabel("Subjects")
plt.ylabel("Scores")
plt.title("Exam Scores Comparison: Class A vs Class B")
plt.legend()

plt.show()

# %% [markdown]
# ---
# ## 📝 Task 3 — Histogram Analysis with Matplotlib
#
# ### Background
# Histograms reveal the **shape of a distribution** — whether it is symmetric, skewed, or has multiple peaks. The number of bins controls the granularity.
#
# ### 🎯 Your Task
# A teacher recorded the following **test scores** for 20 students:
#
# ```
# scores = [45, 55, 60, 62, 65, 65, 68, 70, 70, 72,
#           75, 75, 78, 80, 82, 85, 88, 90, 92, 95]
# ```
#
# **Part A:** Plot a histogram with **5 bins**.
# **Part B:** Below Part A (use `plt.subplot`), plot the **same data with 10 bins**.
# Both plots should have:
# - A different color each
# - Edge color set to black
# - Axis labels and a title describing the bin count
#
# > 💡 **Hint:** Use `plt.subplot(1, 2, 1)` for the first and `plt.subplot(1, 2, 2)` for the second. Call `plt.tight_layout()` at the end.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool, ColumnDataSource
# %matplotlib inline
output_notebook()

# %%
scores = [45, 55, 60, 62, 65, 65, 68, 70, 70, 72,
          75, 75, 78, 80, 82, 85, 88, 90, 92, 95]

plt.figure(figsize=(12, 4))

# YOUR CODE HERE
# Part A: Histogram with 5 bins (subplot 1)
plt.subplot(1, 2, 1)

plt.hist(scores, bins=5, color='skyblue', edgecolor='black')

plt.title("Histogram with 5 Bins")
plt.xlabel("Scores")
plt.ylabel("Number of Students")

# Part B: Histogram with 10 bins (subplot 2)

plt.subplot(1, 2, 2)

plt.hist(scores, bins=10, color='lightgreen', edgecolor='black')

plt.title("Histogram with 10 Bins")
plt.xlabel("Scores")
plt.ylabel("Number of Students")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 4 — Dashboard of 4 Plots with Matplotlib Subplots
#
# ### Background
# Real-world reports often present **multiple charts together** in a grid layout. `plt.subplots(rows, cols)` creates this grid and returns an `axes` array.
#
# ### 🎯 Your Task
# Using the data provided, create a **2×2 subplot dashboard** containing:
#
# | Position | Chart | Data |
# |----------|-------|------|
# | Top-left (0,0) | Line plot | `months` vs `sales` |
# | Top-right (0,1) | Bar chart | `cities` vs `population` |
# | Bottom-left (1,0) | Scatter plot | `hours` vs `grades` |
# | Bottom-right (1,1) | Pie chart | `categories` / `expenses` |
#
# Each subplot must have its own title. The figure should have an overall `suptitle` of `"Monthly Dashboard"`.
#
# > 💡 **Hint:** Access each subplot as `axes[row, col]`. For the pie chart use `axes[1,1].pie(...)`.
# > Use `fig.suptitle("Monthly Dashboard", fontsize=14)` for the main title.

# %%
months     = ['Jan','Feb','Mar','Apr','May','Jun']
sales      = [200, 240, 180, 300, 350, 320]

cities     = ['Karachi','Lahore','Islamabad','Peshawar']
population = [16, 13, 2, 4]   # millions

hours      = [1, 2, 3, 4, 5, 6, 7, 8]
grades     = [50, 55, 60, 65, 72, 78, 85, 90]

categories = ['Food', 'Rent', 'Transport', 'Entertainment']
expenses   = [40, 30, 15, 15]

fig, axes = plt.subplots(2, 2, figsize=(15, 8))

# YOUR CODE HERE
# Top-left: line plot of sales over months
axes[0,0].plot(months, sales, marker='o')
axes[0,0].set_title("Monthly Sales")

# Top-right: bar chart of city populations

axes[0,1].bar(cities, population)
axes[0,1].set_title("City Population")
# Bottom-left: scatter plot of hours vs grades
axes[1,0].scatter(hours, grades)
axes[1,0].set_title("Study Hours vs Grades")

# Bottom-right: pie chart of expenses

axes[1,1].pie(expenses, labels=categories, autopct='%1.1f%%')
axes[1,1].set_title("Monthly Expenses")
fig.suptitle("Monthly Dashboard", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 5 — Seaborn EDA on the `tips` Dataset
#
# ### Background
# Seaborn's statistical plots make it very easy to explore relationships in a dataset. The `tips` dataset records restaurant bill information.
#
# ### 🎯 Your Task
# Load the `tips` dataset and create the following **3 plots** (each in its own cell or in subplots):
#
# **Plot 1 — Box Plot:** Distribution of `tip` amounts grouped by `day`, with `sex` as the hue.
#
# **Plot 2 — Violin Plot:** Distribution of `total_bill` grouped by `time` (Lunch / Dinner).
#
# **Plot 3 — Heatmap:** Correlation matrix of all numeric columns in `tips`, with annotations and the `coolwarm` colormap.
#
# Each plot needs a descriptive title.
#
# > 💡 **Hint for heatmap:** Use `tips.corr(numeric_only=True)` to get the correlation matrix, then pass it to `sns.heatmap(..., annot=True, cmap='coolwarm')`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
tips.head()
# YOUR CODE HERE — Plot 1: Box plot (tip by day, hue=sex)
sns.boxplot(data=tips, x="day", y="tip", hue="sex")
plt.title("Tip Distribution by Day and Gender")
plt.xlabel("Day")
plt.ylabel("Tip Amount")
plt.show()

# %%
# YOUR CODE HERE — Plot 2: Violin plot (total_bill by time)
sns.violinplot(data=tips, x="time", y="total_bill")
plt.title("Distribution of Total Bill by Time of Day")
plt.xlabel("Time")
plt.ylabel("Total Bill")
plt.show()

# %%
# YOUR CODE HERE — Plot 3: Correlation heatmap
corr = tips.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix of Tips Dataset")
plt.show()

# %% [markdown]
# ---
# ## 📝 Task 6 — Seaborn Scatter Plot with Regression Line
#
# ### Background
# `sns.scatterplot` shows raw data points; adding `sns.regplot` or `sns.lmplot` overlays a **linear regression line** with a confidence band, making trends easier to read.
#
# ### 🎯 Your Task
# Using the `tips` dataset:
#
# 1. Create a **scatter plot** of `total_bill` (x-axis) vs `tip` (y-axis), colored by `smoker` status.
# 2. On a **separate plot**, use `sns.regplot` (or `sns.lmplot`) to show the same relationship with a **regression line** (ignore the smoker grouping here).
#
# Both plots need titles, axis labels, and a legend where applicable.
#
# > 💡 **Hint:** For the regression plot try `sns.regplot(x='total_bill', y='tip', data=tips, scatter_kws={'alpha':0.5})`.

# %%
tips = sns.load_dataset('tips')

# YOUR CODE HERE — Part 1: Scatter plot colored by smoker status
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="smoker")

plt.title("Total Bill vs Tip (Colored by Smoker Status)")
plt.xlabel("Total Bill")
plt.ylabel("Tip Amount")

plt.legend(title="Smoker")

plt.show()

# YOUR CODE HERE — Part 2: Regression plot (total_bill vs tip)
sns.regplot(x="total_bill", y="tip", data=tips,
            scatter_kws={'alpha':0.5})

plt.title("Regression Line: Total Bill vs Tip")
plt.xlabel("Total Bill")
plt.ylabel("Tip Amount")

plt.show()

# %% [markdown]
# ---
# ## 📝 Task 7 — Interactive Line Plot with Bokeh
#
# ### Background
# Bokeh creates **interactive, browser-rendered** plots. The `HoverTool` lets users see exact data values when they hover over points.
#
# ### 🎯 Your Task
# Create an **interactive Bokeh line plot** showing website traffic over 7 days:
#
# ```
# days    = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# visitors = [120, 180, 150, 200, 250, 300, 270]
# ```
#
# Requirements:
# - Line width = 2, color of your choice
# - Circle markers on each data point (size = 8)
# - A `HoverTool` that shows the day and visitor count on hover
# - Proper title and axis labels
#
# > 💡 **Hint:** To use HoverTool with plain lists, convert data to a `ColumnDataSource`.
# > `source = ColumnDataSource(data=dict(days=days, visitors=visitors))`
# > Then use `p.line(x='days', y='visitors', source=source)` and
# > `HoverTool(tooltips=[("Day", "@days"), ("Visitors", "@visitors")])`.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool, ColumnDataSource

output_notebook()

days     = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
visitors = [120, 180, 150, 200, 250, 300, 270]

# YOUR CODE HERE
# 1. Create a ColumnDataSource

source = ColumnDataSource(data=dict(days=days, visitors=visitors))
# 2. Create a Bokeh figure with title and axis labels

p = figure(
    title="Website Traffic Over 7 Days",
    x_range=days,
    x_axis_label="Day",
    y_axis_label="Number of Visitors"
)
# 3. Add a line renderer

p.line(x='days', y='visitors', source=source, line_width=2, color="navy")
# 4. Add circle markers

p.circle(x='days', y='visitors', source=source, size=8, color="navy")
# 5. Add a HoverTool
hover = HoverTool(
    tooltips=[
        ("Day", "@days"),
        ("Visitors", "@visitors")
    ]
)

# 6. Show the plot
p.add_tools(hover)

show(p)
# Out:
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="dff169a6-fe15-47c5-9bc6-d86736ac1cd8" data-root-id="p1011" style="display: contents;"></div>

# %% [markdown]
# ---
# ## 📝 Task 8 — Interactive Charts with Plotly Express
#
# ### Background
# Plotly Express (imported as `px`) creates fully interactive charts in one or two lines. Charts support hover info, zoom, and filtering by legend clicks out of the box.
#
# ### 🎯 Your Task
# Use the **built-in `gapminder` dataset** (`px.data.gapminder()`) to create:
#
# **Part A — Animated Scatter Plot:**
# Plot `gdpPercap` (x, log scale) vs `lifeExp` (y), with:
# - Bubble size = `pop`
# - Color = `continent`
# - Animation frame = `year`
# - Title: "GDP vs Life Expectancy Over Time"
#
# **Part B — Bar Chart (2007 snapshot):**
# Filter for `year == 2007` and `continent == 'Asia'`. Plot a bar chart of `country` vs `lifeExp`, sorted descending. Title: "Life Expectancy in Asia (2007)".
#
# > 💡 **Hint for Part A:** `px.scatter(..., animation_frame='year', log_x=True, size='pop', size_max=60)`
# > 💡 **Hint for Part B:** Use `df.sort_values('lifeExp', ascending=False)` before plotting.

# %%
import plotly.express as px

gapminder = px.data.gapminder()
df = px.data.gapminder()

# YOUR CODE HERE — Part A: Animated scatter plot
fig = px.scatter(
    df,
    x="gdpPercap",
    y="lifeExp",
    size="pop",
    color="continent",
    animation_frame="year",
    log_x=True,
    size_max=60,
    title="GDP vs Life Expectancy Over Time"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f7ba595f-971c-4a0a-8e4c-8bb6df0c022e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7ba595f-971c-4a0a-8e4c-8bb6df0c022e")) {                    Plotly.newPlot(                        "f7ba595f-971c-4a0a-8e4c-8bb6df0c022e",                        [{"hovertemplate":"continent=Asia\u003cbr\u003eyear=1952\u003cbr\u003egdpPercap=%{x}\u003cbr\u003elifeExp=%{y}\u003cbr\u003epop=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#636efa","size":[8425333,120447,46886859,4693836,556263527,2125900,372000000,82052000,17272000,5441766,1620914,86459025,607914,8865488,20947571,160000,1439529,6748378,800663,20092996,9182536,507833,41346560,22438691,4005677,1127000,7982342,3661549,8550362,21289402,26246839,1030585,4963829],"sizemode":"area","sizeref":366300.86,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[779.4453145,9867.084765,684.2441716,368.4692856,400.448611,3054.421209,546.5657493,749.6816546,3035.326002,4129.766056,4086.522128,3216.956347,1546.907807,1088.277758,1030.592226,108382.3529,4834.804067,1831.132894,786.5668575,331.0,545.8657228999998,1828.230307,684.5971437999998,1272.880995,6459.554823,2315.138227,1083.53203,1643.485354,1206.947913,757.7974177,605.0664917,1515.5923289999996,781.7175761],"xaxis":"x","y":[28.801,50.93899999999999,37.484,39.417,44.0,60.96,37.37300000000001,37.468,44.869,45.32,65.39,63.03,43.158,50.056,47.453,55.565,55.928,48.463,42.244,36.319,36.157,37.578,43.43600000000001,47.752,39.875,60.396,57.593,45.883,58.5,50.848,40.412,43.16,32.548],"yaxis":"y","type":"scatter"},{"hovertemplate":"continent=Europe\u003cbr\u003eyear=1952\u003cbr\u003egdpPercap=%{x}\u003cbr\u003elifeExp=%{y}\u003cbr\u003epop=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","marker":{"color":"#EF553B","size":[1282697,6927772,8730405,2791000,7274900,3882229,9125183,4334000,4090500,42459667,69145952,7733250,9504000,147962,2952156,47666000,413834,10381988,3327728,25730551,8526050,16630000,6860147,3558137,1489518,28549870,7124673,4815000,22235677,50430000],"sizemode":"area","sizeref":366300.86,"symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[1601.056136,6137.076492,8343.105126999999,973.5331948,2444.286648,3119.23652,6876.14025,9692.385245,6424.519071,7029.809327,7144.114393000002,3530.690067,5263.673816,7267.688428,5210.280328,4931.404154999998,2647.585601,8941.571858,10095.42172,4029.329699,3068.319867,3144.613186,3581.459448,5074.659104,4215.041741,3834.034742,8527.844662000001,14734.23275,1969.10098,9979.508487],"xaxis":"x","y":[55.23,66.8,68.0,53.82,59.6,61.21,66.87,70.78,66.55,67.41,67.5,65.86,64.03,72.49,66.91,65.94,59.164,72.13,72.67,61.31,59.82,61.05,57.996,64.36,65.57,64.94,71.86,69.62,43.585,69.18],"yaxis":"y","type":"scatter"},{"hovertemplate":"continent=Africa\u003cbr\u003eyear=1952\u003cbr\u003egdpPercap=%{x}\u003cbr\u003elifeExp=%{y}\u003cbr\u003epop=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","marker":{"color":"#00cc96","size":[9279525,4232095,1738315,442308,4469979,2445618,5009067,1291695,2682462,153936,14100005,854885,2977019,63149,22223309,216964,1438760,20860941,420702,284320,5581001,2664249,580653,6464046,748747,863308,1019729,4762912,2917802,3838168,1022556,516556,9939217,6446316,485831,3379468,33119096,257700,2534927,60011,2755589,2143249,2526994,14264935,8504667,290243,8322925,1219113,3647735,5824797,2672000,3080907],"sizemode":"area","sizeref":366300.86,"symbol":"circle"},"mode":"markers","name":"Africa","orientation":"v","showlegend":true,"x":[2449.008185,3520.610273,1062.7522,851.2411407,543.2552413,339.2964587, ...

# %%
# YOUR CODE HERE — Part B: Bar chart for Asia in 2007
asia_2007 = df[(df["year"] == 2007) & (df["continent"] == "Asia")]
asia_2007 = asia_2007.sort_values("lifeExp", ascending=False)
fig2 = px.bar(
    asia_2007,
    x="country",
    y="lifeExp",
    color="country",
    title="Life Expectancy in Asia (2007)"
)

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57cffe8a-645e-4001-973d-36997f628e4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57cffe8a-645e-4001-973d-36997f628e4d")) {                    Plotly.newPlot(                        "57cffe8a-645e-4001-973d-36997f628e4d",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Japan"],"xaxis":"x","y":[82.603],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hong Kong, China","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Hong Kong, China","offsetgroup":"Hong Kong, China","orientation":"v","showlegend":true,"textposition":"auto","x":["Hong Kong, China"],"xaxis":"x","y":[82.208],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Israel","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Israel","offsetgroup":"Israel","orientation":"v","showlegend":true,"textposition":"auto","x":["Israel"],"xaxis":"x","y":[80.745],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Singapore","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Singapore","offsetgroup":"Singapore","orientation":"v","showlegend":true,"textposition":"auto","x":["Singapore"],"xaxis":"x","y":[79.972],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Korea, Rep.","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Korea, Rep.","offsetgroup":"Korea, Rep.","orientation":"v","showlegend":true,"textposition":"auto","x":["Korea, Rep."],"xaxis":"x","y":[78.623],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Taiwan","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Taiwan","offsetgroup":"Taiwan","orientation":"v","showlegend":true,"textposition":"auto","x":["Taiwan"],"xaxis":"x","y":[78.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kuwait","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Kuwait","offsetgroup":"Kuwait","orientation":"v","showlegend":true,"textposition":"auto","x":["Kuwait"],"xaxis":"x","y":[77.58800000000002],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oman","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Oman","offsetgroup":"Oman","orientation":"v","showlegend":true,"textposition":"auto","x":["Oman"],"xaxis":"x","y":[75.64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bahrain","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Bahrain","offsetgroup":"Bahrain","orientation":"v","showlegend":true,"textposition":"auto","x":["Bahrain"],"xaxis":"x","y":[75.635],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}\u003cbr\u003elifeExp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","l ...

# %% [markdown]
# ---
# ## 📝 Task 9 — Choose Your Own Visualization
#
# ### Background
# Good data visualization starts with choosing the **right chart type** for your data and message. This task tests that judgment.
#
# ### 🎯 Your Task
# Below is a dataset of a fictional **e-commerce store's weekly performance**:
#
# ```python
# data = {
#     'Day':        ['Mon','Tue','Wed','Thu','Fri','Sat','Sun'],
#     'Orders':     [45,   62,   58,   70,   95,   110,  80 ],
#     'Revenue':    [900,  1240, 1160, 1400, 1900, 2200, 1600],
#     'Returns':    [2,    3,    5,    4,    6,    8,    5   ],
#     'Category':   ['Electronics','Clothing','Books','Electronics','Clothing','Books','Electronics']
# }
# ```
#
# **You must create exactly 3 different chart types** using any combination of Matplotlib, Seaborn, or Plotly. For each chart:
# 1. Clearly state (in a comment) **which chart type you chose and why** it suits that particular relationship
# 2. Include a title, axis labels, and any useful annotations
#
# **Suggested angles to explore** (pick any 3):
# - Trend of `Orders` or `Revenue` over the week
# - Proportion of `Orders` by `Category`
# - Relationship between `Orders` and `Revenue`
# - Comparison of `Returns` vs `Orders` by day
#
# > 💡 There is no single correct answer here. Focus on making each chart **clear and informative**.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df = pd.DataFrame({
    'Day':      ['Mon','Tue','Wed','Thu','Fri','Sat','Sun'],
    'Orders':   [45,   62,   58,   70,   95,  110,   80 ],
    'Revenue':  [900, 1240, 1160, 1400, 1900, 2200, 1600],
    'Returns':  [2,    3,    5,    4,    6,    8,    5   ],
    'Category': ['Electronics','Clothing','Books','Electronics','Clothing','Books','Electronics']
})

# ── Chart 1 ──────────────────────────────────────────────────────────────
# Chart type chosen:
#Line Chart (Trend of Orders Over the Week)
# Why it suits this data:
#A line chart is best for showing trends over time, such as how orders change across days of the week.

# YOUR CODE HERE
# Chart Type: Line Chart
# Reason: Line charts are ideal for visualizing trends over time (days of the week).

plt.figure()

plt.plot(df['Day'], df['Orders'], marker='o')

plt.title("Orders Trend Over the Week")
plt.xlabel("Day")
plt.ylabel("Number of Orders")

for i, val in enumerate(df['Orders']):
    plt.text(i, val+2, str(val))

plt.show()

# %%
# ── Chart 2 ──────────────────────────────────────────────────────────────
# Chart type chosen:
#Pie Chart (Proportion of Orders by Category)
# Why it suits this data:
#First calculate total orders by category.

# YOUR CODE HERE
category_orders = df.groupby('Category')['Orders'].sum()

plt.figure()

plt.pie(category_orders,
        labels=category_orders.index,
        autopct='%1.1f%%',
        startangle=90)

plt.title("Proportion of Orders by Category")

plt.show()

# %%
# ── Chart 3 ──────────────────────────────────────────────────────────────
# Chart type chosen:
#Scatter Plot (Orders vs Revenue)
# Why it suits this data:
#A scatter plot shows the relationship between two numerical variables.

# YOUR CODE HERE

fig = px.scatter(
    df,
    x="Orders",
    y="Revenue",
    text="Day",
    title="Relationship Between Orders and Revenue"
)

fig.update_traces(textposition='top center')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3ab61cff-f96f-4134-b3da-abb9fa672291" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ab61cff-f96f-4134-b3da-abb9fa672291")) {                    Plotly.newPlot(                        "3ab61cff-f96f-4134-b3da-abb9fa672291",                        [{"hovertemplate":"Orders=%{x}\u003cbr\u003eRevenue=%{y}\u003cbr\u003eDay=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"x":[45,62,58,70,95,110,80],"xaxis":"x","y":[900,1240,1160,1400,1900,2200,1600],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo" ...

# %% [markdown]
# ---
# ## 🤔 Reflection Questions
#
# Answer the following in the code cell below as comments:
#
# 1. What is the main advantage of using **Seaborn** over raw Matplotlib for statistical plots?
# 2. When would you choose **Bokeh** over **Plotly**, and vice versa?
# 3. In Task 3, how does changing the number of bins affect your interpretation of the distribution?
# 4. Why is a **pie chart** generally not recommended when you have more than 5–6 categories?
# 5. What does a **violin plot** show that a **box plot** does not?

# %%
# Q1:The main advantage of using **Seaborn** over raw **Matplotlib** for statistical plots is that Seaborn provides **high-level functions specifically designed for statistical data
#visualization**, which makes creating complex plots much easier and faster. It comes with **built-in statistical chart types** such as box plots, violin plots, heatmaps, and regression
#plots, and it automatically applies **attractive themes and color palettes**, so the graphs look more professional without much extra code. Seaborn also works **directly with Pandas DataFrames**,
#allowing you to reference column names easily, while Matplotlib often requires more manual setup. Overall, Seaborn simplifies the process of exploring and visualizing statistical relationships
#in data while still being built on top of Matplotlib.


# Q2:You would choose **Bokeh** when you need to build **custom interactive visualizations or dashboards that integrate closely with Python web applications**. Bokeh allows more control
#over how the visualization behaves in the browser and works well with **Bokeh Server** for creating real-time, interactive data apps where Python handles updates on the backend. On the
#other hand, **Plotly** is preferred when you want to **quickly create highly interactive and visually polished charts with minimal code**. Plotly provides many built-in chart types, easy
#animations, and strong integration with tools like **Dash**, Jupyter notebooks, and web dashboards. In short, **Bokeh is better for customizable interactive web apps**, while **Plotly is
#better for quickly creating rich, interactive, and visually appealing visualizations.**


# Q3:In a histogram, changing the **number of bins** affects how detailed or smooth the distribution appears. If you use **fewer bins**, the histogram becomes more **general and smooth**,
#which may hide important patterns or variations in the data. If you use **more bins**, the histogram shows **more detail**, but it may also introduce noise and make the distribution look
#irregular or harder to interpret. Therefore, choosing the right number of bins is important because it helps reveal the true shape of the data distribution, such as whether it is **normal,
#skewed, or has multiple peaks**.


# Q4:A **pie chart is generally not recommended when there are more than 5–6 categories** because it becomes difficult to clearly compare the sizes of many slices. When too many categories
#are included, the slices become **very small and crowded**, making the chart hard to read and interpret. It also becomes difficult for viewers to **visually compare proportions accurately**
#between similar-sized slices. In such cases, a **bar chart** is usually a better choice because it allows clearer comparison between multiple categories and keeps the visualization easier
#to understand.


# Q5:A **violin plot** shows the **full distribution and density of the data**, which a **box plot does not display**. While a box plot summarizes the data using key statistics such as the
#**median, quartiles, and possible outliers**, it does not reveal how the data values are distributed between those points. A violin plot combines the information of a box plot with a **kernel
#density plot**, allowing you to see the **shape of the distribution**, including whether the data is **skewed, spread out, or has multiple peaks**. This makes violin plots more informative when
#you want to understand the detailed distribution of the data.
